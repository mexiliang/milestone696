# %%
with open('census_api_key.txt') as f:
    lines = f.readlines()
API_KEY = lines[0]

# %% [markdown]
# ## imports

# %%
import pandas as pd
import urllib.request, json 
import requests

# %% [markdown]
# # census data
# * ref: https://api.census.gov/data/2021/acs/acs5/variables.html

# %%
# list years to download
years = [2015, 2020]
max(years)
# Out:
# 2020

# %% [markdown]
# ## create a list of the fields to download, along with a "friendly" name

# %%
# list fields to download. 
#     second column is a friendly name so that I don't need to refer to the codes. 
#     third column indicates if I plan to use it in regression (some fields are just for calculations).
#     4th col is just a note to self
fields = [
    ['B01001_001E', 'population', 1, 'compare to ...1003_001E'], 
    ['B19013_001E', 'median_household_income', 1, ''],
    ['B01002_001E', 'median_age', 1, ''],
    ['B23025_002E', 'labor_force', 0, 'use it for proportions'],
    ['B23025_005E', 'unemployed', 0, 'use it for proportions'],
    ['B15003_022E', 'bachelors_degr', 0, 'use it for proportions'],
    ['B15003_023E', 'masters_degr', 0, 'use it for proportions'],
    ['B11001_001E', 'num_households', 0, 'use it for typ household size'],
    ['B25064_001E', 'median_rent', 1, ''],
    ['B25003_001E', 'total_units_1', 0, 'use for ratio'],
    ['B25003_002E', 'owner_occupied', 0, 'divide by units'],
    # ['B28011_001E', 'internet_access_perc', 1, ''],
    # ['B28011_002E', 'internet_access_with_subscrip', 1, ''],
    ['B25034_010E', 'housing_units_built_last_year', 1, 'they also have 2 years ago etc'],
    ['B11005_001E', 'num_families', 1, ''],
    ['B11005_002E', 'families_with_children', 1, 'under 18'],
    ['B17001_002E', 'below_poverty_level', 1, ''],
    ['B17001_001E', 'total_for_poverty_level_calc', 1, ''],
    ['B11001_007E', 'non_family_households', 1, 'divide by households'],
    ['B08303_001E', 'mean_travel_time_to_work', 1, ''],
    ['B25002_003E', 'vacant_units', 0, 'divide by total units'],
    ['B25002_001E', 'total_units_2', 1, 'redundant?'],
    ['B07001_017E', 'perc_moved_fr_same_county', 1, ''],
    ['B07001_018E', 'perc_moved_fr_other_county', 1, ''],
    ['B07001_019E', 'perc_moved_fr_other_state', 1, ''],
    ['B07001_020E', 'perc_moved_fr_abroad', 1, ''],
    ['B25077_001E', 'median_val_of_owner_occup', 1, ''],
    ['B25018_001E', 'ave_num_rooms', 1, ''],
    ['B25024_002E', 'single_family_units', 0, 'divide by total_units'],
    ['B25024_001E', 'total_units_3', 0, 'use for ratios'],
    ['B08301_010E', 'workers_using_public_trans', 0, 'divide by workers'],
    ['B08301_001E', 'workers', 0, 'for ratios'],
    ['B05002_013E', 'foreign_born', 0, 'divide by population'],
    ['B01002_002E', 'male', 0, 'use it for proportion'],
    ['B01002_003E', 'female', 0, 'use it for proportion'],
    ['B19001_001E', 'income', 0, '? will calc average'],
]
df_fields = pd.DataFrame(fields, columns=['code', 'myname', 'use4regression', 'note'])
# df_fields
df_fields.sort_values('code')
# Out:
#            code                         myname  use4regression  \
# 0   B01001_001E                     population               1
# 2   B01002_001E                     median_age               1
# 31  B01002_002E                           male               0
# 32  B01002_003E                         female               0
# 30  B05002_013E                   foreign_born               0
# 20  B07001_017E      perc_moved_fr_same_county               1
# 21  B07001_018E     perc_moved_fr_other_county               1
# 22  B07001_019E      perc_moved_fr_other_state               1
# 23  B07001_020E           perc_moved_fr_abroad               1
# 29  B08301_001E                        workers               0
# 28  B08301_010E     workers_using_public_trans               0
# 17  B08303_001E       mean_travel_time_to_work               1
# 7   B11001_001E                 num_households               0
# 16  B11001_007E          non_family_households               1
# 12  B11005_001E                   num_families               1
# 13  B11005_002E         families_with_children               1
# 5   B15003_022E                 bachelors_degr               0
# 6   B15003_023E                   masters_degr               0
# 15  B17001_001E   total_for_poverty_level_calc               1
# 14  B17001_002E            below_poverty_level               1
# 33  B19001_001E                         income               0
# 1   B19013_001E        median_household_income               1
# 3   B23025_002E                    labor_force               0
# 4   B23025_005E                     unemployed               0
# 19  B25002_001E                  total_units_2               1
# 18  B25002_003E                   vacant_units               0
# 9   B25003_001E                  total_units_1               0
# 10  B25003_002E                 owner_occupied               0
# 25  B25018_001E                  ave_num_rooms               1
# 27  B25024_001E                  total_units_3               0
# 26  B25024_002E            single_family_units               0
# 11  B25034_010E  housing_units_built_last_year               1
# 8   B25064_001E                    median_rent               1
# 24  B25077_001E      median_val_of_owner_occup               1
#
#                               note
# 0          compare to ...1003_001E
# 2
# 31           use it for proportion
# 32           use it for proportion
# 30            divide by population
# 20
# 21
# 22
# 23
# 29                      for ratios
# 28               divide by workers
# 17
# 7    use it for typ household size
# 16            divide by households
# 12
# 13                        under 18
# 5           use it for proportions
# 6           use it for proportions
# 15
# 14
# 33             ? will calc average
# 1
# 3           use it for proportions
# 4           use it for proportions
# 19                      redundant?
# 18           divide by total units
# 9                    use for ratio
# 10                 divide by units
# 25
# 27                  use for ratios
# 26           divide by total_units
# 11  they also have 2 years ago etc
# 8
# 24

# %% [markdown]
# ## other topics not used:
# * crime (not in census),
# * businesses (not in census),
# * race
# * Proximity to Amenities (parks, schools, shopping centers) (not in census)
# * tax environment, incl local and state (not in census)
# * Proximity to Major Highways or Transport Hubs (not in census)

# %% [markdown]
# ## add the census descriptions to df_fields

# %%
# add the census descriptions to fields_df
textsplitter = ' zzz '
def get_field_descriptions(api_key, year):
    """
    Fetch descriptions for fields for a specific year.
    
    :param api_key: Your Census API Key.
    :param year: Census year.
    :return: Dictionary with field codes as keys and descriptions as values.
    """
    base_url = f"https://api.census.gov/data/{year}/acs/acs5/variables"
    response = requests.get(base_url, params={"key": api_key})
    
    if response.status_code == 200:
        data = response.json()
        # try:
        #     # Extract field code and description from the data
        #     return {var["name"]: var["label"] for var in data["variables"].values()}
        # except TypeError as e:
        #     print(f"Unexpected data structure for year {year}: {data}")
        #     return data
        # descriptions = {row[0]: row[1] for row in data[1:]}
        descriptions = {row[0]: str(row[1]) + textsplitter + str(row[2]) for row in data[1:]}
        return descriptions
    else:
        print(f"Error {response.status_code}: {response.text}")
        return {}

descriptions = {}
descriptions.update(get_field_descriptions(API_KEY, max(years)))
for field in df_fields['code'].to_list():
    this_descr = descriptions.get(field, "Unknown")
    splitted = this_descr.split(textsplitter)
    df_fields.loc[df_fields['code'] == field, 'descr1'] = splitted[0]
    descr2=''
    if len(splitted)>1:
        descr2=splitted[1],
    df_fields.loc[df_fields['code'] == field, 'descr2'] = descr2

df_fields
# Out:
#            code                         myname  use4regression  \
# 0   B01001_001E                     population               1
# 1   B19013_001E        median_household_income               1
# 2   B01002_001E                     median_age               1
# 3   B23025_002E                    labor_force               0
# 4   B23025_005E                     unemployed               0
# 5   B15003_022E                 bachelors_degr               0
# 6   B15003_023E                   masters_degr               0
# 7   B11001_001E                 num_households               0
# 8   B25064_001E                    median_rent               1
# 9   B25003_001E                  total_units_1               0
# 10  B25003_002E                 owner_occupied               0
# 11  B28011_001E           internet_access_perc               1
# 12  B25034_010E  housing_units_built_last_year               1
# 13  B11005_001E                   num_families               1
# 14  B11005_002E         families_with_children               1
# 15  B17001_002E            below_poverty_level               1
# 16  B17001_001E   total_for_poverty_level_calc               1
# 17  B11001_007E          non_family_households               1
# 18  B08303_001E       mean_travel_time_to_work               1
# 19  B25002_003E                   vacant_units               0
# 20  B25002_001E                  total_units_2               1
# 21  B07001_017E      perc_moved_fr_same_county               1
# 22  B07001_018E     perc_moved_fr_other_county               1
# 23  B07001_019E      perc_moved_fr_other_state               1
# 24  B07001_020E           perc_moved_fr_abroad               1
# 25  B25077_001E      median_val_of_owner_occup               1
# 26  B25018_001E                  ave_num_rooms               1
# 27  B25024_002E            single_family_units               0
# 28  B25024_001E                  total_units_3               0
# 29  B08301_010E     workers_using_public_trans               0
# 30  B08301_001E                        workers               0
# 31  B05002_013E                   foreign_born               0
# 32  B01002_002E                           male               0
# 33  B01002_003E                         female               0
# 34  B19001_001E                         income               0
#
#                               note  \
# 0          compare to ...1003_001E
# 1
# 2
# 3           use it for proportions
# 4           use it for proportions
# 5           use it for proportions
# 6           use it for proportions
# 7    use it for typ household size
# 8
# 9                    use for ratio
# 10                 divide by units
# 11
# 12  they also have 2 years ago etc
# 13
# 14                        under 18
# 15
# 16
# 17            divide by households
# 18
# 19           divide by total units
# 20                      redundant?
# 21
# 22
# 23
# 24
# 25
# 26
# 27           divide by total_units
# 28                  use for ratios
# 29               divide by workers
# 30                      for ratios
# 31            divide by population
# 32           use it for proportion
# 33           use it for proportion
# 34             ? will calc average
#
#                                                descr1  \
# 0                                    Estimate!!Total:
# 1   Estimate!!Median household income in the past ...
# 2                     Estimate!!Median age --!!Total:
# 3                   Estimate!!Total:!!In labor force:
# 4   Estimate!!Total:!!In labor force:!!Civilian la...
# 5                 Estimate!!Total:!!Bachelor's degree
# 6                   Estimate!!Total:!!Master's degree
# 7                                    Estimate!!Total:
# 8                         Estimate!!Median gross rent
# 9                                    Estimate!!Total:
# 10                   Estimate!!Total:!!Owner occupied
# 11                                   Estimate!!Total:
# 12               Estimate!!Total:!!Built 1940 to 1949
# 13                                   Estimate!!Total:
# 14  Estimate!!Total:!!Households with one or more ...
# 15  Estimate!!Total:!!Income in the past 12 months...
# 16                                   Estimate!!Total:
# 17            Estimate!!Total:!!Nonfamily households:
# 18                                   Estimate!!Total:
# 19                           Estimate!!Total:!!Vacant
# 20                                   Estimate!!Total:
# 21           Estimate!!Total:!!Same house 1 year ago:
# 22  Estimate!!Total:!!Same house 1 year ago:!!1 to...
# 23  Estimate!!Total:!!Same house 1 year ago:!!5 to...
# 24  Estimate!!Total:!!Same house 1 year ago:!!18 a...
# 25                   Estimate!!Median value (dollars)
# 26                   Estimate!!Median number of rooms
# 27                      Estimate!!Total:!!1, detached
# 28                                   Estimate!!Total:
# 29  Estimate!!Total:!!Public transportation (exclu...
# 30                                   Estimate!!Total:
# 31                    Estimate!!Total:!!Foreign born:
# 32                      Estimate!!Median age --!!Male
# 33                    Estimate!!Median age --!!Female
# 34                                   Estimate!!Total:
#
#                                                descr2
# 0                                          SEX BY AGE
# 1   MEDIAN HOUSEHOLD INCOME IN THE PAST 12 MONTHS ...
# 2                                   MEDIAN AGE BY SEX
# 3   EMPLOYMENT STATUS FOR THE POPULATION 16 YEARS ...
# 4   EMPLOYMENT STATUS FOR THE POPULATION 16 YEARS ...
# 5   EDUCATIONAL ATTAINMENT FOR THE POPULATION 25 Y...
# 6   EDUCATIONAL ATTAINMENT FOR THE POPULATION 25 Y...
# 7             HOUSEHOLD TYPE (INCLUDING LIVING ALONE)
# 8                         MEDIAN GROSS RENT (DOLLARS)
# 9                                              TENURE
# 10                                             TENURE
# 11                INTERNET SUBSCRIPTIONS IN HOUSEHOLD
# 12                               YEAR STRUCTURE BUILT
# 13  HOUSEHOLDS BY PRESENCE OF PEOPLE UNDER 18 YEAR...
# 14  HOUSEHOLDS BY PRESENCE OF PEOPLE UNDER 18 YEAR...
# 15  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY...
# 16  POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY...
# 17            HOUSEHOLD TYPE (INCLUDING LIVING ALONE)
# 18                                TRAVEL TIME TO WORK
# 19                                   OCCUPANCY STATUS
# 20                                   OCCUPANCY STATUS
# 21  GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE ...
# 22  GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE ...
# 23  GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE ...
# 24  GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE ...
# 25                             MEDIAN VALUE (DOLLARS)
# 26                             MEDIAN NUMBER OF ROOMS
# 27                                 UNITS IN STRUCTURE
# 28                                 UNITS IN STRUCTURE
# 29                    MEANS OF TRANSPORTATION TO WORK
# 30                    MEANS OF TRANSPORTATION TO WORK
# 31  PLACE OF BIRTH BY NATIVITY AND CITIZENSHIP STATUS
# 32                                  MEDIAN AGE BY SEX
# 33                                  MEDIAN AGE BY SEX
# 34  HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 202...

# %% [markdown]
# ## create a list of the *calculated* fields and their formulas

# %%
# list the calculated fields
formulas = [
    ['male_prop', 'dfx.male / dfx.population', 0, 'this is just an example'], 
    ['income_ave1', 'dfx.income / dfx.population', 0, 'another example'],
]
df_formulas = pd.DataFrame(formulas, columns=['myname', 'formula', 'use4regression', 'note'])
df_formulas
# Out:
#         myname                      formula  use4regression  \
# 0    male_prop    dfx.male / dfx.population               0
# 1  income_ave1  dfx.income / dfx.population               0
#
#                       note
# 0  this is just an example
# 1          another example

# %%
# see my spreadsheet for a way to calculate mean and standard deviation for binned data like the following: 

a = '''
    ['B19001_002E'], 'income<10', False, 'will calc proportion'],
    ['B19001_003E'], 'income10-15', False, 'will calc proportion'],
    ['B19001_004E'], 'income15-20', False, 'will calc proportion'],
    ['B19001_005E'], 'income20-25', False, 'will calc proportion'],
    ['B19001_006E'], 'income25-30', False, 'will calc proportion'],
    ['B19001_007E'], 'income30-35', False, 'will calc proportion'],
    ['B19001_008E'], 'income35-40', False, 'will calc proportion'],
    ['B19001_009E'], 'income40-45', False, 'will calc proportion'],
    ['B19001_010E'], 'income45-50', False, 'will calc proportion'],
    ['B19001_011E'], 'income50-60', False, 'will calc proportion'],
    ['B19001_012E'], 'income60-75', False, 'will calc proportion'],
    ['B19001_013E'], 'income75-100', False, 'will calc proportion'],
    ['B19001_014E'], 'income100-125', False, 'will calc proportion'],
    ['B19001_015E'], 'income125-150', False, 'will calc proportion'],
    ['B19001_016E'], 'income150-200', False, 'will calc proportion'],
    ['B19001_017E'], 'income200+', False, 'will calc proportion'],
    '''

# %% [markdown]
# ## function to pull the census data

# %%
# function to get the raw data from the census
def get_census_data_by_zip(api_key, fields, year):
    """
    Fetch census data by ZIP Code Tabulation Areas (ZCTAs) for specified fields.
    
    :param api_key: Your Census API Key.
    :param fields: List of fields to fetch.
    :param year: Census year.
    :return: DataFrame with fetched data.
    """
    base_url = f"https://api.census.gov/data/{year}/acs/acs5"
    
    # Combine the fields into a comma-separated string
    fields_str = ",".join(fields)
    
    # Construct the final URL
    url = f"{base_url}?get={fields_str}&for=zip%20code%20tabulation%20area:*"
    
    headers = {
        "Content-Type": "application/json",
    }
    
    # Make the API request
    response = requests.get(url, headers=headers, params={"key": api_key})
    
    if response.status_code == 200:
        data = response.json()
        # Convert data to DataFrame
        df = pd.DataFrame(data[1:], columns=data[0])
        df['year'] = year
        return df
    else:
        print(f"Error {response.status_code}: {response.text}")
        return None

# %%
# a = get_census_data_by_zip(API_KEY, download_fields, 2015)
# b = get_census_data_by_zip(API_KEY, download_fields, 2020)
# print(a.shape)
# print(b.shape)
# c = pd.concat([a, b])
# print(c.shape)
# c.head()
# c.sample(10)

# %% [markdown]
# ## get the data

# %%
# get the data
download_fields = [item[0] for item in fields]
dfraw = pd.DataFrame()
for year in years:
    print(year)
    temp_df = get_census_data_by_zip(API_KEY, download_fields, year)
    dfraw = pd.concat([dfraw, temp_df])
    print(dfraw.shape)
# Out:
# 2015
# Error 400: error: error: unknown variable 'B28011_001E'
# (0, 0)
# 2020
# (33120, 37)

# %%
# rename the field codes with 'myname'
dict1 = pd.Series(df_fields.myname.values,index=df_fields.code).to_dict()
dfraw.rename(columns=dict1, inplace=True)
# dfraw.head()

# %%
# rename the zip column, and re order columns
dfraw.rename(columns = {'zip code tabulation area':'zipcode'}, inplace = True)
# cols=['state', 'zipcode', 'year']
cols=['zipcode', 'year']
dfraw = dfraw[cols + [c for c in dfraw.columns if c not in cols]]
dfraw.head()
# Out:
#   zipcode  year population median_household_income median_age labor_force  \
# 0   00601  2020      16773                   14398       42.9        5229
# 1   00602  2020      37083                   16771       43.6       11764
# 2   00603  2020      45652                   15786       43.2       14679
# 3   00606  2020       6231                   14980       45.1        1612
# 4   00610  2020      26502                   20167       43.2        9150
#
#   unemployed bachelors_degr masters_degr num_households  ...  \
# 0       1599           1644          155           5555  ...
# 1        913           4210         1065          12901  ...
# 2       2575           5367         1686          19431  ...
# 3        157            319          163           1983  ...
# 4        877           2610          585           8864  ...
#
#   median_val_of_owner_occup ave_num_rooms single_family_units total_units_3  \
# 0                     81800           4.9                5849          7282
# 1                     85600           4.8               12666         17510
# 2                    116000           4.9               16397         24453
# 3                     86000           4.2                2478          2789
# 4                     87100           4.9                9233         12454
#
#   workers_using_public_trans workers foreign_born  male female income
# 0                          0    3588           38  41.6   43.8   5555
# 1                         83   10811          255  42.9   45.0  12901
# 2                         28   11201          544  41.4   44.8  19431
# 3                          0    1455          260  44.7   45.6   1983
# 4                         26    8208          141  41.6   45.6   8864
#
# [5 rows x 37 columns]

# %% [markdown]
# ## add the calculated fields (and calculated values)

# %%
# make the columns numeric
dfraw = dfraw.apply(pd.to_numeric)

# %%
df_formulas
# Out:
#         myname                      formula  use4regression  \
# 0    male_prop    dfx.male / dfx.population               0
# 1  income_ave1  dfx.income / dfx.population               0
#
#                       note
# 0  this is just an example
# 1          another example

# %%
dfraw.head()
# Out:
#    zipcode  year  population  median_household_income  median_age  \
# 0      601  2020       16773                    14398        42.9
# 1      602  2020       37083                    16771        43.6
# 2      603  2020       45652                    15786        43.2
# 3      606  2020        6231                    14980        45.1
# 4      610  2020       26502                    20167        43.2
#
#    labor_force  unemployed  bachelors_degr  masters_degr  num_households  ...  \
# 0         5229        1599            1644           155            5555  ...
# 1        11764         913            4210          1065           12901  ...
# 2        14679        2575            5367          1686           19431  ...
# 3         1612         157             319           163            1983  ...
# 4         9150         877            2610           585            8864  ...
#
#    median_val_of_owner_occup  ave_num_rooms  single_family_units  \
# 0                      81800            4.9                 5849
# 1                      85600            4.8                12666
# 2                     116000            4.9                16397
# 3                      86000            4.2                 2478
# 4                      87100            4.9                 9233
#
#    total_units_3  workers_using_public_trans  workers  foreign_born  male  \
# 0           7282                           0     3588            38  41.6
# 1          17510                          83    10811           255  42.9
# 2          24453                          28    11201           544  41.4
# 3           2789                           0     1455           260  44.7
# 4          12454                          26     8208           141  41.6
#
#    female  income
# 0    43.8    5555
# 1    45.0   12901
# 2    44.8   19431
# 3    45.6    1983
# 4    45.6    8864
#
# [5 rows x 37 columns]

# %%
# do the calculated fields
dfx = dfraw
for newcol, formula, aa, bb in formulas:
    # print(newcol + ' = ' + formula)
    dfx = pd.eval(newcol + ' = ' + formula, target = dfx)

dfx.head()
# Out:
#    zipcode  year  population  median_household_income  median_age  \
# 0      601  2020       16773                    14398        42.9
# 1      602  2020       37083                    16771        43.6
# 2      603  2020       45652                    15786        43.2
# 3      606  2020        6231                    14980        45.1
# 4      610  2020       26502                    20167        43.2
#
#    labor_force  unemployed  bachelors_degr  masters_degr  num_households  ...  \
# 0         5229        1599            1644           155            5555  ...
# 1        11764         913            4210          1065           12901  ...
# 2        14679        2575            5367          1686           19431  ...
# 3         1612         157             319           163            1983  ...
# 4         9150         877            2610           585            8864  ...
#
#    single_family_units  total_units_3  workers_using_public_trans  workers  \
# 0                 5849           7282                           0     3588
# 1                12666          17510                          83    10811
# 2                16397          24453                          28    11201
# 3                 2478           2789                           0     1455
# 4                 9233          12454                          26     8208
#
#    foreign_born  male  female  income  male_prop  income_ave1
# 0            38  41.6    43.8    5555   0.002480     0.331187
# 1           255  42.9    45.0   12901   0.001157     0.347895
# 2           544  41.4    44.8   19431   0.000907     0.425633
# 3           260  44.7    45.6    1983   0.007174     0.318247
# 4           141  41.6    45.6    8864   0.001570     0.334465
#
# [5 rows x 39 columns]

# %%
dfx[dfx['zipcode']==90266]
# Out:
#        zipcode  year  population  median_household_income  median_age  \
# 30101    90266  2020       35064                   153926        42.9
#
#        labor_force  unemployed  bachelors_degr  masters_degr  num_households  \
# 30101        16965         843           10285          5244           13313
#
#        ...  single_family_units  total_units_3  workers_using_public_trans  \
# 30101  ...                10239          14952                         113
#
#        workers  foreign_born  male  female  income  male_prop  income_ave1
# 30101    15591          4572  42.9    43.0   13313   0.001223     0.379677
#
# [1 rows x 39 columns]

# %%
# generate list of fields for regression.

# %%
# convert to long format
